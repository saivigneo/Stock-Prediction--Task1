# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-learn
# !pip install tensorflow
# Out:
# Requirement already satisfied: numpy in c:\users\hicet\anaconda3\lib\site-packages (1.24.3)
# Requirement already satisfied: pandas in c:\users\hicet\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hicet\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\hicet\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\hicet\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hicet\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\hicet\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hicet\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: numpy>=1.17 in c:\users\hicet\anaconda3\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hicet\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hicet\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hicet\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hicet\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hicet\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hicet\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\hicet\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\hicet\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\hicet\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hicet\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\hicet\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\hicet\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: tensorflow in c:\users\hicet\anaconda3\lib\site-packages (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: setuptools in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (63.4.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.56.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.14.1)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (16.0.0)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.5.26)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.31.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.23.4)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.7.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.24.3)
# Requirement already satisfied: packaging in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (21.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.3.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\hicet\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hicet\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\hicet\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hicet\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hicet\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\hicet\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.22.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hicet\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\hicet\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\hicet\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.13.0->tensorflow) (3.0.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hicet\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\hicet\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (5.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hicet\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\hicet\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.26.11)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\hicet\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hicet\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hicet\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\hicet\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\hicet\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\hicet\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.2.2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
df = pd.read_csv('Infosysstockpricedata.csv') 
df.head(15)
# Out:
#           Date      Open      High       Low     Close  Adj Close    Volume
# 0   1996-01-01  0.794921  0.796679  0.791015  0.796679   0.549483  204800.0
# 1   1996-01-02  0.794921  0.798828  0.793457  0.793457   0.547260  204800.0
# 2   1996-01-03  0.798828  0.798828  0.798828  0.798828   0.550965  102400.0
# 3   1996-01-04  0.791015  0.794921  0.791015  0.793554   0.547327  307200.0
# 4   1996-01-05  0.784179  0.784179  0.784179  0.784179   0.540861   51200.0
# 5   1996-01-08  0.784179  0.791015  0.785156  0.789062   0.544229  358400.0
# 6   1996-01-09  0.789062  0.781250  0.771484  0.780273   0.538167  870400.0
# 7   1996-01-10  0.780273  0.775390  0.771484  0.773437   0.533452  358400.0
# 8   1996-01-11  0.779296  0.791015  0.773437  0.791015   0.545576  819200.0
# 9   1996-01-12  0.787109  0.787109  0.781250  0.786621   0.542545  358400.0
# 10  1996-01-15  0.776367  0.785156  0.776367  0.777832   0.536484  307200.0
# 11  1996-01-16  0.777832  0.781250  0.712890  0.781250   0.538841  358400.0
# 12  1996-01-17  0.781250  0.783203  0.771484  0.773828   0.533722  768000.0
# 13  1996-01-18  0.773828  0.776367  0.769531  0.776367   0.535473  204800.0
# 14  1996-01-19  0.771484  0.771484  0.768066  0.768554   0.530084  512000.0

# %%
#preprocess the data
data = df.filter(['Close']).values
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# %%
#spliiting the dataset into training dataset 
train_data_len = int(len(data) * 0.8)
train_data = scaled_data[:train_data_len, :]
test_data = scaled_data[train_data_len:, :]

# %%
#Prepare the training data
x_train = []
y_train = []
for i in range(60, len(train_data)):
    x_train.append(train_data[i - 60:i, 0])
    y_train.append(train_data[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
#building lstm model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dense(units=25))
model.add(Dense(units=1))

# %%
# training the lstm model
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, batch_size=1, epochs=10)
# Out:
# Epoch 1/10
# 5140/5140 [==============================] - 76s 14ms/step - loss: nan
# Epoch 2/10
# 5140/5140 [==============================] - 75s 15ms/step - loss: nan
# Epoch 3/10
# 5140/5140 [==============================] - 74s 14ms/step - loss: nan
# Epoch 4/10
# 5140/5140 [==============================] - 81s 16ms/step - loss: nan
# Epoch 5/10
# 5140/5140 [==============================] - 74s 14ms/step - loss: nan
# Epoch 6/10
# 5140/5140 [==============================] - 73s 14ms/step - loss: nan
# Epoch 7/10
# 5140/5140 [==============================] - 75s 15ms/step - loss: nan
# Epoch 8/10
# 5140/5140 [==============================] - 79s 15ms/step - loss: nan
# Epoch 9/10
# 5140/5140 [==============================] - 77s 15ms/step - loss: nan
# Epoch 10/10
# 5140/5140 [==============================] - 74s 14ms/step - loss: nan

# %%
# testing the lstm model
x_test = []
y_test = data[train_data_len + 60:, :]
for i in range(len(test_data) - 60):
    x_test.append(test_data[i:i + 60, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
# Predicting the model 
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 39/39 [==============================] - 0s 10ms/step

# %%
# Plot the predicted and actual prices of infoysys stock 
plt.figure(figsize=(12, 6))
plt.plot(df['Close'].values, label='Real Price')
plt.plot(range(train_data_len + 60, len(data)), predictions, label='Predicted Price')
plt.xlabel('Time period')
plt.ylabel('Stock Price')
plt.title('Stock Price Prediction')
plt.legend()
plt.show()
